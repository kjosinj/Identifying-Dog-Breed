# %%
import os
import numpy as np, pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as implt
from PIL import Image 
import keras, cv2, shutil, keras_preprocessing, requests, math, glob, datetime
import tensorflow as tf
from keras import layers
from keras.models import Sequential, Model 
from keras.layers import Lambda, Input, Dense, Dropout, Flatten, Conv2D, MaxPooling2D, Activation, SpatialDropout2D, GlobalAveragePooling2D 
from keras.callbacks import EarlyStopping
from keras_preprocessing import image
from keras_preprocessing.image import ImageDataGenerator
from keras.applications.inception_v3 import InceptionV3, preprocess_input as inception_preprocessor
from keras.applications.xception import Xception, preprocess_input as xception_preprocessor
from keras.applications.inception_resnet_v2 import InceptionResNetV2, preprocess_input as inc_resnet_preprocessor
from keras.applications.nasnet import NASNetLarge, preprocess_input as nasnet_preprocessor
from sklearn.utils import shuffle
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.datasets import load_files
from io import BytesIO
import seaborn as sns
import xml.etree.ElementTree as ET
from tensorflow.keras.utils import load_img, img_to_array
from keras.applications.vgg16 import preprocess_input
from pathlib import Path
# %load_ext tensorboard
shutil.rmtree('./logs', ignore_errors=True)

# %%
train_dir = "C:/Users/kjosh/OneDrive/Documents/UChicago/ADSP 31009 - Machine Learning & Predictive Analytics/Final Project/Train_Test_Split/train/"

# %%
test_dir = "C:/Users/kjosh/OneDrive/Documents/UChicago/ADSP 31009 - Machine Learning & Predictive Analytics/Final Project/Train_Test_Split/test/"

# %%
target_size = (128, 128)
input_shape = (128, 128, 3)

# %%
batch_size = 256

# %%
train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    shear_range = 0.3,
    zoom_range = 0.3,
    horizontal_flip=True,
    rotation_range = 30
)

# %%
train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=target_size,
        batch_size=batch_size,
        class_mode='categorical')
# Out:
# Found 17651 images belonging to 120 classes.

# %%
test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255)

# %%
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=target_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 4475 images belonging to 120 classes.

# %%
inputs = keras.Input(shape=input_shape)

base_xcept_model = keras.applications.Xception(
    weights = 'imagenet',
    input_shape=input_shape,
    include_top=False)
base_xcept_model.trainable = False

# %%
x = base_xcept_model.output
x = Dropout(0.5)(x) #Add dropout layer with a dropout rate of 0.5
x = GlobalAveragePooling2D()(x)
outputs = Dense(120, activation='softmax')(x)
model = keras.Model(base_xcept_model.input, outputs)
for layer in base_xcept_model.layers: layer.trainable = False

# %%
optimizer = keras.optimizers.Adam(learning_rate=0.01, epsilon=0.1)

# %%
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# %%
early_stoppage_callback = EarlyStopping(monitor='val_accuracy', mode='max', min_delta=0.001, patience=7, restore_best_weights = True)

# %%
history = model.fit(train_generator, 
            steps_per_epoch = 20,
            epochs=50,
            verbose=1,
            validation_data=test_generator, 
            callbacks=[early_stoppage_callback]
            )
# Out:
# Epoch 1/50
# 20/20 [==============================] - 476s 24s/step - loss: 5.0748 - accuracy: 0.0143 - val_loss: 4.7139 - val_accuracy: 0.0320
# Epoch 2/50
# 20/20 [==============================] - 454s 23s/step - loss: 4.5001 - accuracy: 0.0611 - val_loss: 3.9940 - val_accuracy: 0.1537
# Epoch 3/50
# 20/20 [==============================] - 373s 19s/step - loss: 3.8863 - accuracy: 0.1779 - val_loss: 3.2688 - val_accuracy: 0.3202
# Epoch 4/50
# 20/20 [==============================] - 248s 13s/step - loss: 3.3046 - accuracy: 0.2951 - val_loss: 2.6302 - val_accuracy: 0.4559
# Epoch 5/50
# 20/20 [==============================] - 245s 12s/step - loss: 2.7955 - accuracy: 0.3924 - val_loss: 2.1442 - val_accuracy: 0.5432
# Epoch 6/50
# 20/20 [==============================] - 249s 13s/step - loss: 2.4326 - accuracy: 0.4520 - val_loss: 1.8108 - val_accuracy: 0.5944
# Epoch 7/50
# 20/20 [==============================] - 242s 12s/step - loss: 2.1669 - accuracy: 0.4863 - val_loss: 1.5915 - val_accuracy: 0.6226
# Epoch 8/50
# 20/20 [==============================] - 287s 15s/step - loss: 2.0202 - accuracy: 0.5182 - val_loss: 1.4470 - val_accuracy: 0.6371
# Epoch 9/50
# 20/20 [==============================] - 469s 24s/step - loss: 1.8557 - accuracy: 0.5393 - val_loss: 1.3472 - val_accuracy: 0.6588
# Epoch 10/50
# 20/20 [==============================] - 408s 21s/step - loss: 1.8106 - accuracy: 0.5410 - val_loss: 1.2785 - val_accuracy: 0.6673
# Epoch 11/50
# 20/20 [==============================] - 325s 16s/step - loss: 1.7446 - accuracy: 0.5561 - val_loss: 1.2264 - val_accuracy: 0.6758
# Epoch 12/50
# 20/20 [==============================] - 211s 11s/step - loss: 1.6618 - accuracy: 0.5609 - val_loss: 1.1896 - val_accuracy: 0.6784
# Epoch 13/50
# 20/20 [==============================] - 213s 11s/step - loss: 1.6705 - accuracy: 0.5631 - val_loss: 1.1580 - val_accuracy: 0.6780
# Epoch 14/50
# 20/20 [==============================] - 213s 11s/step - loss: 1.6226 - accuracy: 0.5659 - val_loss: 1.1391 - val_accuracy: 0.6838
# Epoch 15/50
# 20/20 [==============================] - 215s 11s/step - loss: 1.6051 - accuracy: 0.5670 - val_loss: 1.1244 - val_accuracy: 0.6869
# Epoch 16/50
# 20/20 [==============================] - 244s 12s/step - loss: 1.5520 - accuracy: 0.5836 - val_loss: 1.0974 - val_accuracy: 0.6896
# Epoch 17/50
# 20/20 [==============================] - 395s 20s/step - loss: 1.5504 - accuracy: 0.5777 - val_loss: 1.0861 - val_accuracy: 0.6956
# Epoch 18/50
# 20/20 [==============================] - 309s 16s/step - loss: 1.4793 - accuracy: 0.5949 - val_loss: 1.0740 - val_accuracy: 0.6943
# Epoch 19/50
# 20/20 [==============================] - 217s 11s/step - loss: 1.5072 - accuracy: 0.5880 - val_loss: 1.0645 - val_accuracy: 0.6979
# Epoch 20/50
# 20/20 [==============================] - 224s 11s/step - loss: 1.4888 - accuracy: 0.5877 - val_loss: 1.0545 - val_accuracy: 0.6968
# Epoch 21/50
# 20/20 [==============================] - 223s 11s/step - loss: 1.4584 - accuracy: 0.6041 - val_loss: 1.0524 - val_accuracy: 0.7015
# Epoch 22/50
# 20/20 [==============================] - 226s 12s/step - loss: 1.4497 - accuracy: 0.5990 - val_loss: 1.0470 - val_accuracy: 0.6941
# Epoch 23/50
# 20/20 [==============================] - 222s 11s/step - loss: 1.4585 - accuracy: 0.5924 - val_loss: 1.0358 - val_accuracy: 0.6994
# Epoch 24/50
# 20/20 [==============================] - 225s 11s/step - loss: 1.4410 - accuracy: 0.6025 - val_loss: 1.0245 - val_accuracy: 0.7066
# Epoch 25/50
# 20/20 [==============================] - 224s 11s/step - loss: 1.4016 - accuracy: 0.6158 - val_loss: 1.0242 - val_accuracy: 0.7044
# Epoch 26/50
# 20/20 [==============================] - 222s 11s/step - loss: 1.4218 - accuracy: 0.6062 - val_loss: 1.0221 - val_accuracy: 0.7035
# Epoch 27/50
# 20/20 [==============================] - 222s 11s/step - loss: 1.4377 - accuracy: 0.6051 - val_loss: 1.0160 - val_accuracy: 0.7097
# Epoch 28/50
# 20/20 [==============================] - 222s 11s/step - loss: 1.4027 - accuracy: 0.6086 - val_loss: 1.0188 - val_accuracy: 0.7044
# Epoch 29/50
# 20/20 [==============================] - 303s 16s/step - loss: 1.4126 - accuracy: 0.6217 - val_loss: 1.0112 - val_accuracy: 0.7053
# Epoch 30/50
# 20/20 [==============================] - 386s 20s/step - loss: 1.3772 - accuracy: 0.6146 - val_loss: 1.0078 - val_accuracy: 0.7091
# Epoch 31/50
# 20/20 [==============================] - 385s 20s/step - loss: 1.3646 - accuracy: 0.6207 - val_loss: 1.0048 - val_accuracy: 0.7122
# Epoch 32/50
# 20/20 [==============================] - 388s 20s/step - loss: 1.3884 - accuracy: 0.6109 - val_loss: 0.9978 - val_accuracy: 0.7099
# Epoch 33/50
# 20/20 [==============================] - 398s 20s/step - loss: 1.3431 - accuracy: 0.6227 - val_loss: 1.0042 - val_accuracy: 0.7106
# Epoch 34/50
# 20/20 [==============================] - 386s 20s/step - loss: 1.3209 - accuracy: 0.6256 - val_loss: 0.9942 - val_accuracy: 0.7104
# Epoch 35/50
# 20/20 [==============================] - 385s 20s/step - loss: 1.3361 - accuracy: 0.6271 - val_loss: 0.9951 - val_accuracy: 0.7131
# Epoch 36/50
# 20/20 [==============================] - 407s 21s/step - loss: 1.3282 - accuracy: 0.6301 - val_loss: 0.9984 - val_accuracy: 0.7084
# Epoch 37/50
# 20/20 [==============================] - 391s 20s/step - loss: 1.3434 - accuracy: 0.6244 - val_loss: 0.9978 - val_accuracy: 0.7117
# Epoch 38/50
# 20/20 [==============================] - 395s 20s/step - loss: 1.2850 - accuracy: 0.6418 - val_loss: 0.9931 - val_accuracy: 0.7146
# Epoch 39/50
# 20/20 [==============================] - 392s 20s/step - loss: 1.3218 - accuracy: 0.6287 - val_loss: 0.9880 - val_accuracy: 0.7106
# Epoch 40/50
# 20/20 [==============================] - 393s 20s/step - loss: 1.2745 - accuracy: 0.6430 - val_loss: 0.9859 - val_accuracy: 0.7180
# Epoch 41/50
# 20/20 [==============================] - 386s 20s/step - loss: 1.2961 - accuracy: 0.6374 - val_loss: 0.9851 - val_accuracy: 0.7117
# Epoch 42/50
# 20/20 [==============================] - 238s 12s/step - loss: 1.2986 - accuracy: 0.6338 - val_loss: 0.9794 - val_accuracy: 0.7153
# Epoch 43/50
# 20/20 [==============================] - 220s 11s/step - loss: 1.3129 - accuracy: 0.6356 - val_loss: 0.9781 - val_accuracy: 0.7135
# Epoch 44/50
# 20/20 [==============================] - 223s 11s/step - loss: 1.2825 - accuracy: 0.6346 - val_loss: 0.9808 - val_accuracy: 0.7144
# Epoch 45/50
# 20/20 [==============================] - 222s 11s/step - loss: 1.2663 - accuracy: 0.6340 - val_loss: 0.9797 - val_accuracy: 0.7144
# Epoch 46/50
# 20/20 [==============================] - 222s 11s/step - loss: 1.3096 - accuracy: 0.6293 - val_loss: 0.9798 - val_accuracy: 0.7191
# Epoch 47/50
# 20/20 [==============================] - 225s 11s/step - loss: 1.2709 - accuracy: 0.6391 - val_loss: 0.9865 - val_accuracy: 0.7162
# Epoch 48/50
# 20/20 [==============================] - 226s 12s/step - loss: 1.3003 - accuracy: 0.6387 - val_loss: 0.9754 - val_accuracy: 0.7160
# Epoch 49/50
# 20/20 [==============================] - 225s 11s/step - loss: 1.2766 - accuracy: 0.6366 - val_loss: 0.9701 - val_accuracy: 0.7184
# Epoch 50/50
# 20/20 [==============================] - 347s 18s/step - loss: 1.2705 - accuracy: 0.6336 - val_loss: 0.9740 - val_accuracy: 0.7164

# %%
history_df = pd.DataFrame(history.history)

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
class_labels = []
for i in os.listdir('C:/Users/kjosh/OneDrive/Documents/UChicago/ADSP 31009 - Machine Learning & Predictive Analytics/Final Project/Train_Test_Split/train/'):
    class_labels.append(i)

# %%
predictions = []
confidence = []

# %%
example_images = "C:/Users/kjosh/OneDrive/Documents/UChicago/ADSP 31009 - Machine Learning & Predictive Analytics/Final Project/Test_Images/"

# %%
for image in os.listdir(example_images): 
    my_image = load_img(os.path.join(example_images,image), target_size=target_size)
    my_image = img_to_array(my_image)
    my_image = my_image/255
    my_image = my_image.reshape((1, my_image.shape[0], my_image.shape[1], my_image.shape[2]))
    prediction = model.predict(my_image)
    predicted_class_index = np.argmax(prediction)
    predictions.append(class_labels[predicted_class_index])
    confidence.append(round(prediction[0][predicted_class_index] * 100, 2))
# Out:
# 1/1 [==============================] - 1s 968ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 70ms/step

# %%
# Get a list of all image files in the directory
image_files = [file for file in os.listdir(example_images)]

# Set up the plot with multiple subplots
num_images = len(image_files)
num_cols = 2  # Number of columns in the plot
num_rows = (num_images - 1) // num_cols + 1  # Number of rows in the plot

fig, axes = plt.subplots(num_rows, num_cols, figsize=(12, 12))

# Loop through the image files and plot them
for i, file in enumerate(image_files):
    row = i // num_cols
    col = i % num_cols

    # Load the image using matplotlib's imread function
    image_path = os.path.join(example_images, file)
    image = plt.imread(image_path)

    # Plot the image on the corresponding subplot
    axes[row, col].imshow(image)
    axes[row, col].axis('off')
    axes[row, col].text(0.5, -0.1, f'Actual Breed/Class: {os.path.splitext(file)[0]}', fontsize=8, ha='center', transform=axes[row, col].transAxes)
    axes[row, col].text(0.5, 1.06, f'Predicted Breed/Class: {predictions[i]}', fontsize=8, ha='center', transform=axes[row, col].transAxes)
# Adjust the spacing between subplots
plt.tight_layout()

# Show the plot
plt.show()

# %%
terrier_images = "C:/Users/kjosh/OneDrive/Documents/UChicago/ADSP 31009 - Machine Learning & Predictive Analytics/Final Project/Terrier_Test_Images/"

# %%
ter_predictions = []
ter_confidence = []

# %%
for image in os.listdir(terrier_images): 
    my_image = load_img(os.path.join(terrier_images,image), target_size=target_size)
    my_image = img_to_array(my_image)
    my_image = my_image/255
    my_image = my_image.reshape((1, my_image.shape[0], my_image.shape[1], my_image.shape[2]))
    prediction = model.predict(my_image)
    predicted_class_index = np.argmax(prediction)
    ter_predictions.append(class_labels[predicted_class_index])
    ter_confidence.append(round(prediction[0][predicted_class_index] * 100, 2))
# Out:
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 59ms/step

# %%
# Get a list of all image files in the directory
image_files = [file for file in os.listdir(terrier_images)]

# Set up the plot with multiple subplots
num_images = len(image_files)
num_cols = 2  # Number of columns in the plot
num_rows = 2  # Number of rows in the plot

fig, axes = plt.subplots(num_rows, num_cols, figsize=(12, 12))

# Loop through the image files and plot them
for i, file in enumerate(image_files):
    row = i // num_cols
    col = i % num_cols

    # Load the image using matplotlib's imread function
    image_path = os.path.join(terrier_images, file)
    image = plt.imread(image_path)

    # Plot the image on the corresponding subplot
    axes[row, col].imshow(image)
    axes[row, col].axis('off')
    axes[row, col].text(0.5, -0.1, f'Actual Breed/Class: {os.path.splitext(file)[0]}', fontsize=8, ha='center', transform=axes[row, col].transAxes)
    axes[row, col].text(0.5, 1.06, f'Predicted Breed/Class: {ter_predictions[i]}', fontsize=8, ha='center', transform=axes[row, col].transAxes)
# Adjust the spacing between subplots
plt.tight_layout()

# Show the plot
plt.show()
